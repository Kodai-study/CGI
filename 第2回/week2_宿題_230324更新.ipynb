# %% [markdown]
# ## 問題文
# 任意の$m\times n$行列$A$をインプットデータとして、そのフロベニウスノルムを返り値とする関数を作成してください。全成分の二乗和のルートをフロベニウスノルムと言います。ここでは、複数の要素に対してある一つの値を返す集約関数を想定しています。
#
# 例えば、行列
# $$
# A=
# \begin{pmatrix}
#   3 & 2 & 1 \\
#   5 & 3 & 7 \\
#   1 & 1 & 1
# \end{pmatrix}$$
# は、次のようにnumpyの配列として扱います。
#
# ```python
# A = np.array([[3,2,1],[5,3,7],[1,1,1]])
# ```
#
# 提出するときは、以下の点に注意してください。
# >- 以下の関数`homework`の`!!WRITE ME!!`に処理を書いてください。(**「`!!WRITE ME!!`」は消して、記入してください。**)
# >- 実際の提出は記述された`homework`関数全てになり、**提出はOmnicampus内の宿題の欄から今週の課題を選択後、提出内容に関数を貼り付けてから[Pythonコード提出]を押してください。**
# >- 返り値は数値型です。
# >- 関数は1つにまとめてください。

# %%
# インポート
import numpy as np
import numpy.linalg as linalg

# !!WRITE ME!!に処理を記入する（homework関数を提出することに注意）

# 1つ上のマークダウンに書いてある要件を満たす関数を作成
# 引数はA
# 戻り値はmy_result


A = np.array([[3, 2, 1], [5, 3, 7], [1, 1, 1]])


def homework(A):
    # Aの2乗和を求める
    my_result = np.sum(A**2)
    my_result = np.sqrt(my_result)
    return my_result


homework(A)
# Out:
# 10.0
